# %%
from matplotlib import pyplot as plt
import numpy as np
results=np.loadtxt("DD_Lighton_Adjacency.csv")
feat_axis=[10, 25, 50, 100, 250, 500, 1000,5000]    
nodes_num=6
samples_num=2000
plt.semilogx(feat_axis,100*results,linewidth=1.8)

plt.xlabel("Number of random features")
plt.ylabel("Test accuracy")
plt.title("Lighon_adjacency with different numbers of random features")
plt.grid()
plt.legend(["samples_num: {}\n graphlet_size:{}".fortmat(samples_num,nodes_num)])
plt.savefig('DD-Lighton random features with adjacency matrix.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-76ef8d090242> in <module>
#      11 plt.title("Lighon_adjacency with different numbers of random features")
#      12 plt.grid()
# ---> 13 plt.legend(["samples_num: {}\n graphlet_size:{}".fortmat(samples_num,nodes_num)])
#      14 plt.savefig('DD-Lighton random features with adjacency matrix.png')
#
# AttributeError: 'str' object has no attribute 'fortmat'
